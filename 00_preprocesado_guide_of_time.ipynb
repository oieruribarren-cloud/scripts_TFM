# %%
from pathlib import Path
import pandas as pd

base = Path(r"C:\Users\oieru\OneDrive\Escritorio\MASTER\00-TFM\00-TFM_FINAL\DataBase\Limpio2\Conversations")

for archivo in base.glob("*_Conversations/GuideOfTimes.csv"):
    df = pd.read_csv(archivo, sep=";")
    df["Event"] = df["Event"].str.split("_").str[0]
    df.to_csv(archivo, sep=";", index=False)

print("Hecho")
# Out:
# Hecho
